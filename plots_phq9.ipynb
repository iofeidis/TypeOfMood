# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import plots
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Plots of users' Label Ratios in two time periods
#
# $$ratio_{label_{i}} = \frac{\frac{NumberOfLabel_{i}^{period_{2}}}{NumberOfAllLabels^{period_{2}}}}{\frac{NumberOfLabel_{i}^{period_{1}}}{NumberOfAllLabels^{period_{1}}}}$$
#
# ## Periods:
#     - Period1 : dates up to 2020-02-28
#     - Period2 : dates after 2020-02-28

# %% [markdown]
# ## iOS

# %%
os.chdir('/home/jason/Documents/Thesis/TypingData/iOS')
data = pd.read_csv('statistics_total_added_info.csv')
df = pd.DataFrame(data)
plots.label_distribution_sorted(df, 'Mood', 'Happy', 'iOS')

# %%
os.chdir('/home/jason/Documents/Thesis/TypingData/iOS')
data = pd.read_csv('statistics_total_added_info.csv')
df = pd.DataFrame(data)
plots.label_distribution_sorted(df, 'Mood', 'Stressed+Sick', 'iOS')

# %%
os.chdir('/home/jason/Documents/Thesis/TypingData/iOS')
data = pd.read_csv('statistics_total_added_info.csv')
df = pd.DataFrame(data)
plots.label_distribution_sorted(df, 'Physical_State', 'Tired+Sick', 'iOS')

# %%
os.chdir('/home/jason/Documents/Thesis/TypingData/iOS')
data = pd.read_csv('statistics_total_added_info.csv')
df = pd.DataFrame(data)
plots.label_distribution_sorted(df, 'Physical_State', 'Relaxed', 'iOS')

# %% [markdown]
# ## Android

# %%
os.chdir('/home/jason/Documents/Thesis/TypingData/Android')
data = pd.read_csv('statistics_total_added_clean.csv')
df = pd.DataFrame(data)
plots.label_distribution_sorted(df, 'Mood', 'Happy', 'Android')

# %%
os.chdir('/home/jason/Documents/Thesis/TypingData/Android')
data = pd.read_csv('statistics_total_added_clean.csv')
df = pd.DataFrame(data)
plots.label_distribution_sorted(df, 'Mood', 'Stressed+Sad', 'Android')

# %%
os.chdir('/home/jason/Documents/Thesis/TypingData/Android')
data = pd.read_csv('statistics_total_added_clean.csv')
df = pd.DataFrame(data)
plots.label_distribution_sorted(df, 'Physical_State', 'Tiredness+Sickness', 'Android')

# %%
os.chdir('/home/jason/Documents/Thesis/TypingData/Android')
data = pd.read_csv('statistics_total_added_clean.csv')
df = pd.DataFrame(data)
plots.label_distribution_sorted(df, 'Physical_State', 'Relaxation', 'Android')
